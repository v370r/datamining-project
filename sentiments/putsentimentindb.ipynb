# %%
import sqlite3
import pandas as pd
from sentiment import SentimentAnalyzer
from tqdm import tqdm

# %%
con = sqlite3.connect("processdDB.db")

df = pd.read_sql("SELECT * FROM processdDB", con)

# reports = []
# for i,group in df.groupby("name"):
#     for j,report in group.groupby("time"):
#         reports.append(report[report["type"]=="10-K"])
#         #a = report[report["type"]=="10-K"].copy()
#         #b = report[report["type"] == "10-Q"].copy()
#         #reports.append(a)
#         #reports.append(b)

# %%
tags = ["RF","URFC","Comments","Cybersecurity","Properties","MDAFC","QQDMR","FSSD"]
sans = SentimentAnalyzer()
index_sentiment = {}

for target in tags:
    tdf = df[df["tag"] == target]
    print(f"Current tag {target}")
    for i,row in tqdm(tdf.iterrows(),total=len(tdf)):
        sans.add_text(row["value"])
        index_sentiment[i] = sans.get_sentiment()
# Out:
# Current tag RF
# ...
#   2%|▏         | 1/45 [00:05<03:54,  5.33s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 10
#       8 for i,row in tqdm(tdf.iterrows(),total=len(tdf)):
#       9     sans.add_text(row["value"])
# ---> 10     index_sentiment[i] = sans.get_sentiment()
#
# File ~/Documents/CSCI 4502 Data Mining/project/sentiment.py:49, in SentimentAnalyzer.get_sentiment(self)
#      47 for chunk in self.chunks:
#      48     with torch.no_grad():
# ---> 49         logits = self.model(**chunk).logits
#      50     # Subtract or add probabliity of positive or negative
#      51     retarr.append(logits.argmax())
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
# ...
